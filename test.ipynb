# %% [markdown]
# # My first Python Model Training Test

# %% [markdown]
# # Load Data

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/hewageuhcu/Python-Model-Training-Test/refs/heads/main/synthetic_molecular_data_2000.csv')
df
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion  logS
# 0      2.1854  167.768                  9                 0.0 -1.68
# 1      4.7782  161.140                  4                 0.0 -1.94
# 2      3.7940  457.815                  4                 0.4 -1.77
# 3      3.1940  162.296                  6                 0.8 -3.06
# 4      1.2021  172.377                  3                 0.8 -3.70
# ...       ...      ...                ...                 ...   ...
# 1995   3.4563  248.948                  8                 0.8 -5.05
# 1996   4.8048  200.481                  5                 0.4 -4.49
# 1997   0.8103  227.558                  3                 0.6 -5.06
# 1998   0.7567  288.473                  2                 0.6 -0.28
# 1999   1.7698  122.615                  2                 0.2 -3.57
#
# [2000 rows x 5 columns]

# %% [markdown]
# # Data Preperation

# %% [markdown]
# ## Data Seperation as x and y

# %%
y = df['logS']
y
# Out:
# 0      -1.68
# 1      -1.94
# 2      -1.77
# 3      -3.06
# 4      -3.70
#         ...
# 1995   -5.05
# 1996   -4.49
# 1997   -5.06
# 1998   -0.28
# 1999   -3.57
# Name: logS, Length: 2000, dtype: float64

# %%
X = df.drop('logS', axis=1)
X
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 0      2.1854  167.768                  9                 0.0
# 1      4.7782  161.140                  4                 0.0
# 2      3.7940  457.815                  4                 0.4
# 3      3.1940  162.296                  6                 0.8
# 4      1.2021  172.377                  3                 0.8
# ...       ...      ...                ...                 ...
# 1995   3.4563  248.948                  8                 0.8
# 1996   4.8048  200.481                  5                 0.4
# 1997   0.8103  227.558                  3                 0.6
# 1998   0.7567  288.473                  2                 0.6
# 1999   1.7698  122.615                  2                 0.2
#
# [2000 rows x 4 columns]

# %% [markdown]
# ## Data Splitting

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=100)

# %%
X_train
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 1260   1.7105  141.942                  4                 0.6
# 916    1.8251  383.853                  3                 0.0
# 532    4.9849  182.579                  4                 0.0
# 1159   0.6316  181.572                  3                 0.6
# 1584   4.9450  233.062                  4                 0.6
# ...       ...      ...                ...                 ...
# 1879   3.0426  154.121                  4                 0.8
# 1895   3.7988  421.012                  4                 0.0
# 1859   3.7782  425.140                  5                 0.6
# 792    2.7765  306.293                  5                 0.6
# 1544   4.8332  439.097                  2                 0.6
#
# [1600 rows x 4 columns]

# %%
X_test
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 1025   2.6340  218.264                  1                 0.8
# 1208   1.7313  247.645                  3                 0.4
# 1055   2.0782  485.842                  8                 0.6
# 367    4.5741  301.389                  6                 0.8
# 815    2.8348  397.232                  4                 0.8
# ...       ...      ...                ...                 ...
# 807    4.6651  122.752                  6                 0.8
# 711    3.1804  283.082                  6                 0.6
# 1541   0.9809  414.061                  9                 0.6
# 1001   2.9386  408.507                  2                 0.8
# 687    1.7599  236.139                  9                 0.8
#
# [400 rows x 4 columns]

# %% [markdown]
# # **Model Building**

# %% [markdown]
# ###**Linear Regression**

# %% [markdown]
# ####**Training the Model**

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ####**Applying the Model to Make a Prediction**

# %%
y_lr_train_pred = lr.predict(X_train)
y_lr_test_pred = lr.predict(X_test)

# %%
#        -3.00649349, -2.88447156, -3.06467043, -3.01493046, -2.94202998,
#        -3.02193835, -3.03899602, -2.97574098, -3.08296698, -3.08664778,
#        -2.87067805, -3.02046883, -3.01919744, -3.04362418, -2.97856282,
#        -3.02844366, -2.91281637, -3.03250037, -2.92950201, -2.94112872,
#        -3.00045278, -3.03548594, -2.92905548, -3.00202074, -3.05281847,
#        -2.9209283 , -3.04376803, -2.96942636, -3.04792944, -3.02384252,
#        -2.96236831, -2.99291536, -3.07587115, -2.92516477, -3.05810637])

# %%
y_lr_train_pred
# Out:
# array([-2.99042597, -2.99048866, -2.95414462, ..., -2.96411189,
#        -2.98404452, -2.89858064])

# %% [markdown]
# ####**Evaluate Model Performance**

# %%
y_train
# Out:
# 1260   -2.64
# 916    -5.16
# 532    -3.10
# 1159   -5.04
# 1584   -4.34
#         ...
# 1879   -2.03
# 1895   -3.62
# 1859   -3.69
# 792    -2.77
# 1544   -1.68
# Name: logS, Length: 1600, dtype: float64

# %%
y_lr_train_pred
# Out:
# array([-2.99042597, -2.99048866, -2.95414462, ..., -2.96411189,
#        -2.98404452, -2.89858064])

# %%
from sklearn.metrics import mean_squared_error, r2_score
lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2 = r2_score(y_train, y_lr_train_pred)

lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %%
print('LR MSE (Train): ',lr_train_mse)
print('LR R2 (Train): ',lr_train_r2)
print('LR MSE (Test): ',lr_test_mse)
print('LR R2 (Test): ',lr_test_r2)
# Out:
# LR MSE (Train):  3.0065852457462108
# LR R2 (Train):  0.0009071404924682058
# LR MSE (Test):  3.049031843254339
# LR R2 (Test):  -6.249878591302327e-05

# %%
lr_results=pd.DataFrame(['Linear Regression',lr_train_mse, lr_train_r2,lr_test_mse, lr_test_r2]).transpose()
lr_results.columns=['Method','Training MSE', 'Training R2', 'Test MSE','Test R2']

# %%
lr_results
# Out:
#               Method Training MSE Training R2  Test MSE   Test R2
# 0  Linear Regression     3.006585    0.000907  3.049032 -0.000062

# %%
lr_train_mse
# Out:
# 3.0065852457462108

# %%
lr_train_r2
# Out:
# 0.0009071404924682058

# %%
lr_test_mse
# Out:
# 3.049031843254339

# %%
lr_test_r2
# Out:
# -6.249878591302327e-05

# %% [markdown]
# ###Random Forest

# %% [markdown]
# ####**Training the Model**

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(max_depth=2, random_state=100)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %% [markdown]
# ####Applying the Model to Make a Prediction

# %%
y_rf_train_pred = rf.predict(X_train)
y_rf_test_pred = rf.predict(X_test)

# %% [markdown]
# ####Evaluate Model Performance

# %%
from sklearn.metrics import mean_squared_error, r2_score

rf_train_mse = mean_squared_error(y_train, y_rf_train_pred)
rf_train_r2 = r2_score(y_train, y_rf_train_pred)

rf_test_mse = mean_squared_error(y_test, y_rf_test_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

# %%
rf_results = pd.DataFrame(['Random Forest',rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
rf_results.columns = ['Method','Training MSE', 'Training R2', 'Test MSE', 'Test R2']
rf_results
# Out:
#           Method Training MSE Training R2  Test MSE   Test R2
# 0  Random Forest     2.958739    0.016806  3.058044 -0.003019

# %% [markdown]
# ###**Model Comparison**

# %%
df_models = pd.concat([lr_results, rf_results] , axis=0)
df_models
# Out:
#               Method Training MSE Training R2  Test MSE   Test R2
# 0  Linear Regression     3.006585    0.000907  3.049032 -0.000062
# 0      Random Forest     2.958739    0.016806  3.058044 -0.003019

# %%
df_models.reset_index()
# Out:
#    index             Method Training MSE Training R2  Test MSE   Test R2
# 0      0  Linear Regression     3.006585    0.000907  3.049032 -0.000062
# 1      0      Random Forest     2.958739    0.016806  3.058044 -0.003019

# %% [markdown]
# #Data Visualization of Prediction Results

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(5,5))
plt.scatter(x=y_train, y=y_lr_train_pred, c='#7CAE00' ,alpha=0.3)

z = np.polyfit(y_train, y_lr_train_pred, 1)
p = np.poly1d(z)


plt.plot(y_train, p(y_train), '#F8766D')
plt.ylabel('Predict LogS')
plt.xlabel('Experimental LogS')
# Out:
# Text(0.5, 0, 'Experimental LogS')
